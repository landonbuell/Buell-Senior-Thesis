# %%
import os
dir = 'C:/Users/Landon/Documents/aiff_audio'

import os 
if __name__ == "__main__": 
    for (root,dirs,files) in os.walk(dir, topdown=True): 
        print(root) 
        
        os.chdir(root)
        for file in files:
            if file.endswith('.wav'):
                os.remove(file)
                
        print(dirs) 
        print(files) 
        print('--------------------------------')
# Out:
# C:/Users/Landon/Documents/aiff_audio
# ['Bassoon', 'Bass_Trombone', 'Bb_Trumpet', 'Clarinets', 'Double_Bass', 'Flutes', 'Horns', 'Oboes', 'Saxophones', 'Tenor_Trombone', 'Tuba', 'Violas', 'Violins', 'Violoncellos']
# []
# --------------------------------
# C:/Users/Landon/Documents/aiff_audio\Bassoon
# ['Bassoon.ff.stereo']
# []
# --------------------------------
# C:/Users/Landon/Documents/aiff_audio\Bassoon\Bassoon.ff.stereo
# []
# ...
