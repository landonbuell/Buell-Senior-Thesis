# %%
"""
Landon Buell
Instument Classifier v0
Feature Space Analysis
3 May 2020
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols = ['Rise Time', 'Decay Time', 'RMS Frame Energy', 'RMS < 10% of max',
       'RMS < 25% of max', 'RMS < 50% of max', 'RMS < 75% of max', 'Avg TSF',
       'Target']
FRAME = pd.read_csv('C:/Users/Landon/Documents/GitHub/Buell-Senior-Thesis/ \
                    Instrument_Classifier_v0/INST_CLF_v0/extdata/Output.csv',
                  index_col=0,names=cols)
FRAME.head(10)
# Out:
#        Rise Time   Decay Time  RMS Frame Energy  RMS < 10% of max  \
# NaN    Rise Time   Decay Time  RMS Frame Energy  RMS < 10% of max
# 0.0  0.108547406  0.169966549       0.441319054               216
# 1.0  0.108547406  0.169966549       0.441319054               216
# 2.0  0.105429419  0.512574362       0.490025197               218
# 3.0  0.105429419  0.512574362       0.490025197               218
# 4.0  0.117654568  0.709485929       0.425772195               192
# 5.0  0.117654568  0.709485929       0.425772195               192
# 6.0  0.300974783  0.166908498       0.351850535               232
# 7.0  0.300974783  0.166908498       0.351850535               232
# 8.0  0.068617223   0.61182853       0.612040586               210
#
#      RMS < 25% of max  RMS < 50% of max  RMS < 75% of max    Avg TSF  Target
# NaN  RMS < 25% of max  RMS < 50% of max  RMS < 75% of max    Avg TSF  Target
# 0.0               205               176               131   2.87E-10       2
# 1.0               205               176               131   2.87E-10       2
# 2.0               213               184               138   1.50E-09       2
# 3.0               213               184               138   1.50E-09       2
# 4.0               152               123                99   1.76E-09       2
# 5.0               152               123                99   1.76E-09       2
# 6.0               215               185               134  -7.55E-10       2
# 7.0               215               185               134  -7.55E-10       2
# 8.0               197               179               161   8.17E-10       2

# %%
FRAME.columns
# Out:
# Index(['Rise Time', 'Decay Time', 'RMS Frame Energy', 'RMS < 10% of max',
#        'RMS < 25% of max', 'RMS < 50% of max', 'RMS < 75% of max', 'Avg TSF',
#        'Target'],
#       dtype='object')

# %%
y = FRAME['Target']
y = y.to_numpy()
int_to_fam = {0:'Brass',1:'String',2:'High_Winds',3:'Low_Winds'}
#y = [int_to_fam[y] for y in y]
y
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
def Plot_Features(DATA,X1,X2,Y,savename=''):
    """ Plot 2D feature space, color code by class """
    plt.figure(figsize=(16,8))
    plt.xlabel(str(X1),size=20,weight='bold')
    plt.ylabel(str(X2),size=20,weight='bold')
    
    plt.scatter(x=DATA[X1],y=DATA[X2],c=,cmap='Set1')
                
    plt.vlines(0,0,1,color='black')
    plt.hlines(0,0,1,color='black')
    #plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.savefig(savename+'.png')
    plt.show()
# Out:
#   File "<ipython-input-45-630ca1bff6be>", line 7
#     plt.scatter(x=DATA[X1],y=DATA[X2],c=,cmap='Set1')
#                                         ^
# SyntaxError: invalid syntax

# %%
""" Plot RISE vs. DECAY """
Plot_Features(FRAME,'Rise Time','Decay Time',Y=y,
             savename="Rise_Decay")
# Out:
# No handles with labels found to put in legend.

# %%
""" Plot RMS vs. RMS <10 % """
Plot_Features(FRAME,'RMS Frame Energy','RMS < 10% of max',Y=y,
             savename="RMS_10")
# Out:
# No handles with labels found to put in legend.
