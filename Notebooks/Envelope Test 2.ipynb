# %%
"""
Landon Buell
30 December 2019
"""

import numpy as np
import matplotlib.pyplot as plt
import os
#import winsound

import scipy.signal as signal
import scipy.io.wavfile as sciowav

int_dir = 'C:/Users/Landon/Documents/GitHub/Buell-Senior-Thesis/Notebooks'
wav_dir = 'C:/Users/Landon/Documents/wav_audio'

# %%
        #### LOAD .WAV FILE ####

filename = 'Viola.arco.sulG.G4.L.wav'
os.chdir(wav_dir)
rate,waveform = sciowav.read(filename)
os.chdir(int_dir)
windsound.play(waveform)
waveform = waveform/np.max(waveform)
indexes = np.arange(0,len(waveform),1)
time = indexes/44100
print("Points in wav file:",len(waveform))
print("Time of wav file:",len(waveform)/44100)

plt.figure(figsize=(16,4))
plt.plot(indexes,waveform,color='blue')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ad5407b1197e> in <module>
#       5 rate,waveform = sciowav.read(filename)
#       6 os.chdir(int_dir)
# ----> 7 windsound.play(waveform)
#       8 waveform = waveform/np.max(waveform)
#       9 indexes = np.arange(0,len(waveform),1)
#
# NameError: name 'windsound' is not defined

# %%
hgt = 0.2
thresh = 1
#dist

peaks,properties = signal.find_peaks(x=waveform,height=hgt,threshold=thresh)
                                     

plt.figure(figsize=(16,4))
plt.hlines(y=[-heights,+heights],
           xmin=indexes[0],xmax=indexes[-1],color="black")


plt.plot(indexes,waveform,color='blue')
plt.plot(peaks,waveform[peaks],'go')
plt.xlim(10000,130000)
plt.grid()
plt.show()
