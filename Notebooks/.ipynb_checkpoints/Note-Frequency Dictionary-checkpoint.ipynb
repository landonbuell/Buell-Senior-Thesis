# %%
"""
Landon Buell
30 December 2019
"""

import numpy as np
import pandas as pd

# %%
notefreq = {}
ref = 440

notes = np.array([])
for octave in np.arange(0,9):
    for letter in ['A','Bb','B','C','Db','D','Eb','E','F','Gb','G','Ab'] :   
        name = letter+str(octave)
        notes = np.append(notes,name)
        

steps = np.arange(-int(12*4),+int(12*5),1,dtype=int)
freqs = np.array([440*(2**(n/12)) for n in steps])

# %%
print(len(notes))
print(len(freqs))
# Out:
# 108
# 108

# %%
frame = pd.DataFrame(data=np.array([notes,freqs]).transpose(),columns=['Note','Frequency'])

pd.set_option('display.max_rows', None)
print(frame)
# Out:
#     Note           Frequency
# 0     A0                27.5
# 1    Bb0   29.13523509488062
# 2     B0   30.86770632850775
# 3     C0   32.70319566257483
# 4    Db0   34.64782887210901
# 5     D0   36.70809598967594
# 6    Eb0  38.890872965260115
# 7     E0   41.20344461410875
# 8     F0  43.653528929125486
# 9    Gb0    46.2493028389543
# 10    G0  48.999429497718666
# 11   Ab0   51.91308719749314
# 12    A1                55.0
# 13   Bb1   58.27047018976124
# 14    B1    61.7354126570155
# 15    C1   65.40639132514966
# 16   Db1   69.29565774421802
# 17    D1   73.41619197935188
# 18   Eb1   77.78174593052023
# 19    E1    82.4068892282175
# 20    F1   87.30705785825097
# 21   Gb1    92.4986056779086
# 22    G1   97.99885899543733
# 23   Ab1  103.82617439498628
# 24    A2               110.0
# 25   Bb2  116.54094037952248
# 26    B2  123.47082531403103
# 27    C2   130.8127826502993
# 28   Db2  138.59131548843604
# 29    D2   146.8323839587038
# 30   Eb2  155.56349186104046
# 31    E2  164.81377845643496
# 32    F2  174.61411571650194
# 33   Gb2   184.9972113558172
# 34    G2  195.99771799087463
# 35   Ab2  207.65234878997256
# 36    A3               220.0
# 37   Bb3  233.08188075904496
# 38    B3  246.94165062806206
# 39    C3   261.6255653005986
# 40   Db3   277.1826309768721
# 41    D3   293.6647679174076
# 42   Eb3   311.1269837220809
# 43    E3   329.6275569128699
# 44    F3   349.2282314330039
# 45   Gb3   369.9944227116344
# 46    G3  391.99543598174927
# 47   Ab3   415.3046975799451
# 48    A4               440.0
# 49   Bb4   466.1637615180899
# 50    B4   493.8833012561241
# 51    C4   523.2511306011972
# 52   Db4   554.3652619537442
# 53    D4   587.3295358348151
# 54   Eb4   622.2539674441618
# 55    E4   659.2551138257398
# 56    F4   698.4564628660078
# 57   Gb4   739.9888454232688
# 58    G4   783.9908719634985
# 59   Ab4   830.6093951598903
# 60    A5               880.0
# 61   Bb5   932.3275230361799
# 62    B5   987.7666025122483
# 63    C5  1046.5022612023945
# 64   Db5  1108.7305239074883
# 65    D5  1174.6590716696303
# 66   Eb5  1244.5079348883237
# 67    E5  1318.5102276514797
# 68    F5  1396.9129257320155
# 69   Gb5  1479.9776908465376
# 70    G5   1567.981743926997
# 71   Ab5  1661.2187903197805
# 72    A6              1760.0
# 73   Bb6  1864.6550460723597
# 74    B6   1975.533205024496
# 75    C6   2093.004522404789
# 76   Db6  2217.4610478149766
# 77    D6    2349.31814333926
# 78   Eb6  2489.0158697766474
# 79    E6    2637.02045530296
# 80    F6   2793.825851464031
# 81   Gb6   2959.955381693075
# 82    G6  3135.9634878539946
# 83   Ab6   3322.437580639561
# 84    A7              3520.0
# 85   Bb7  3729.3100921447194
# 86    B7   3951.066410048992
# 87    C7   4186.009044809578
# 88   Db7   4434.922095629953
# 89    D7    4698.63628667852
# 90   Eb7   4978.031739553295
# 91    E7    5274.04091060592
# 92    F7   5587.651702928062
# 93   Gb7    5919.91076338615
# 94    G7   6271.926975707989
# 95   Ab7   6644.875161279122
# 96    A8              7040.0
# 97   Bb8   7458.620184289437
# 98    B8   7902.132820097988
# 99    C8   8372.018089619156
# 100  Db8   8869.844191259906
# 101   D8   9397.272573357044
# 102  Eb8    9956.06347910659
# 103   E8  10548.081821211836
# 104   F8  11175.303405856126
# 105  Gb8    11839.8215267723
# 106   G8  12543.853951415975
# 107  Ab8  13289.750322558246
