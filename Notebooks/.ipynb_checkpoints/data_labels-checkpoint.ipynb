# %%
"""
Landon Buell
1 Jan 2020
"""

import numpy as np
import os
import pandas as pd

datapath = 'C:/Users/Landon/Documents/wav_audio'
outpath = 'C:/Users/Landon/Documents/GitHub/Buell-Senior-Thesis/Frequency_Classifier_v0'

# %%
def read_directory(dir,ext):
    """Read all files in given directory path"""
    output = np.array([])                   # array to hold filenames
    for roots,dirs,files in os.walk(dir):   # all objects in parent path
        for file in files:                  # files in list of files
            if file.endswith(ext):          # if match ext
                output = np.append(output,file)                
    return output                           # return the list of files

filenames = read_directory(datapath,'.wav')
print("Number of files:",len(filenames))
# Out:
# Number of files: 2172

# %%
cntr = -1
labels = []
instrument_names = []

for name in filenames:
    instrument = name.split('.')[0]
    if instrument in instrument_names:
        labels.append(int(cntr))      
    else:
        cntr += 1
        instrument_names.append(instrument)
        labels.append(int(cntr))

# %%
print(len(labels))
print(len(filenames))
# Out:
# 2172
# 2172

# %%
frame = pd.DataFrame(data=np.array([filenames,labels]).transpose(),columns=['Filenames','Class'])

# %%
frame
# Out:
#                        Filenames Class
# 0         AltoFlute.vib.A3.L.wav     1
# 1         AltoFlute.vib.A3.R.wav     1
# 2         AltoFlute.vib.A4.L.wav     1
# 3         AltoFlute.vib.A4.R.wav     1
# 4         AltoFlute.vib.A5.L.wav     1
# 5         AltoFlute.vib.A5.R.wav     1
# 6        AltoFlute.vib.Ab3.L.wav     1
# 7        AltoFlute.vib.Ab3.R.wav     1
# 8        AltoFlute.vib.Ab4.L.wav     1
# 9        AltoFlute.vib.Ab4.R.wav     1
# 10       AltoFlute.vib.Ab5.L.wav     1
# 11       AltoFlute.vib.Ab5.R.wav     1
# 12        AltoFlute.vib.B3.L.wav     1
# 13        AltoFlute.vib.B3.R.wav     1
# 14        AltoFlute.vib.B4.L.wav     1
# 15        AltoFlute.vib.B4.R.wav     1
# 16        AltoFlute.vib.B5.L.wav     1
# 17        AltoFlute.vib.B5.R.wav     1
# 18       AltoFlute.vib.Bb3.L.wav     1
# 19       AltoFlute.vib.Bb3.R.wav     1
# 20       AltoFlute.vib.Bb4.L.wav     1
# 21       AltoFlute.vib.Bb4.R.wav     1
# 22       AltoFlute.vib.Bb5.L.wav     1
# 23       AltoFlute.vib.Bb5.R.wav     1
# 24        AltoFlute.vib.C4.L.wav     1
# 25        AltoFlute.vib.C4.R.wav     1
# 26        AltoFlute.vib.C5.L.wav     1
# 27        AltoFlute.vib.C5.R.wav     1
# 28        AltoFlute.vib.C6.L.wav     1
# 29        AltoFlute.vib.C6.R.wav     1
# ...                          ...   ...
# 2142   Violin.arco.sulG.B4.L.wav    19
# 2143   Violin.arco.sulG.B4.R.wav    19
# 2144  Violin.arco.sulG.Bb3.L.wav    19
# 2145  Violin.arco.sulG.Bb3.R.wav    19
# 2146  Violin.arco.sulG.Bb4.L.wav    19
# 2147  Violin.arco.sulG.Bb4.R.wav    19
# 2148   Violin.arco.sulG.C4.L.wav    19
# 2149   Violin.arco.sulG.C4.R.wav    19
# 2150   Violin.arco.sulG.C5.L.wav    19
# 2151   Violin.arco.sulG.C5.R.wav    19
# 2152   Violin.arco.sulG.D4.L.wav    19
# 2153   Violin.arco.sulG.D4.R.wav    19
# 2154   Violin.arco.sulG.D5.L.wav    19
# 2155   Violin.arco.sulG.D5.R.wav    19
# 2156  Violin.arco.sulG.Db4.L.wav    19
# 2157  Violin.arco.sulG.Db4.R.wav    19
# 2158  Violin.arco.sulG.Db5.L.wav    19
# 2159  Violin.arco.sulG.Db5.R.wav    19
# 2160   Violin.arco.sulG.E4.L.wav    19
# 2161   Violin.arco.sulG.E4.R.wav    19
# 2162  Violin.arco.sulG.Eb4.L.wav    19
# 2163  Violin.arco.sulG.Eb4.R.wav    19
# 2164   Violin.arco.sulG.F4.L.wav    19
# 2165   Violin.arco.sulG.F4.R.wav    19
# 2166   Violin.arco.sulG.G3.L.wav    19
# 2167   Violin.arco.sulG.G3.R.wav    19
# 2168   Violin.arco.sulG.G4.L.wav    19
# 2169   Violin.arco.sulG.G4.R.wav    19
# 2170  Violin.arco.sulG.Gb4.L.wav    19
# 2171  Violin.arco.sulG.Gb4.R.wav    19
#
# [2172 rows x 2 columns]

# %%
os.chdir(outpath)
frame.to_csv('Instrument_labels.txt',sep='\t')
